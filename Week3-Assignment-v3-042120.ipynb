# %% [markdown]
# # Week 3 Assignment \\ All Parts
# ## Please scroll down for answers to Questions 2 and 3...
# ### JC

# %% [markdown]
# ### --------------------------------
# # Question 1: Building a Dataframe of Toronto Boroughs and Neighborhoods

# %%
# installing pandas
import pandas as pd
import numpy as np
import requests
print('done!')
# Out:
# done!

# %% [markdown]
# ### Building the initial dataframe

# %%
# establish url 
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
# establishing dataframe
data = pd.read_html(url)[0]

# %%
# double-checking dataframe
data
# Out:
#     Postal code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                  NaN
# 1                                                  NaN
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# ..                                                 ...
# 175                                                NaN
# 176                                                NaN
# ...

# %%
# confirming number of rows and columns
data.shape
# Out:
# (180, 3)

# %% [markdown]
# ### Revising the dataframe, per the course instructions - changing column names, dropping Not assigned, etc.

# %%
# renaming Postal Code column
tor_df = data.rename(columns={'Postal code':'PostalCode'})

# %%
# confirming new dataframe
tor_df.head()
# Out:
#   PostalCode           Borough                Neighborhood
# 0        M1A      Not assigned                         NaN
# 1        M2A      Not assigned                         NaN
# 2        M3A        North York                   Parkwoods
# 3        M4A        North York            Victoria Village
# 4        M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
# dropping 'Not assigned' Boroughs from dataframe
tor_df = tor_df[tor_df.Borough != 'Not assigned']

# %%
# confirming the drops were done properly
tor_df
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# ..         ...               ...
# 160        M8X         Etobicoke
# 165        M4Y  Downtown Toronto
# 168        M7Y      East Toronto
# 169        M8Y         Etobicoke
# 178        M8Z         Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# 5                    Lawrence Manor / Lawrence Heights
# 6         Queen's Park / Ontario Provincial Government
# ..                                                 ...
# 160    The Kingsway / Montgomery Road / Old Mill North
# 165                               Church and Wellesley
# 168              Business reply mail Processing CentrE
# ...

# %%
#replacing / with , in the "neighborhood" column
tor_df = tor_df.replace('/', ',', regex=True)

# %%
tor_df.head()
# Out:
#   PostalCode           Borough                                  Neighborhood
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 5        M6A        North York             Lawrence Manor , Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government

# %%
#reset the dataframe index 
tor_df = tor_df.reset_index()
tor_df
# Out:
#      index PostalCode           Borough  \
# 0        2        M3A        North York
# 1        3        M4A        North York
# 2        4        M5A  Downtown Toronto
# 3        5        M6A        North York
# 4        6        M7A  Downtown Toronto
# ..     ...        ...               ...
# 98     160        M8X         Etobicoke
# 99     165        M4Y  Downtown Toronto
# 100    168        M7Y      East Toronto
# 101    169        M8Y         Etobicoke
# 102    178        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4         Queen's Park , Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway , Montgomery Road , Old Mill North
# ...

# %%
tor_df = tor_df.drop(columns = 'index')
tor_df
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                           Regent Park , Harbourfront
# 3                    Lawrence Manor , Lawrence Heights
# 4         Queen's Park , Ontario Provincial Government
# ..                                                 ...
# 98     The Kingsway , Montgomery Road , Old Mill North
# 99                                Church and Wellesley
# 100              Business reply mail Processing CentrE
# ...

# %% [markdown]
# ### Final Dataframe Shape

# %%
# printing the shape of the dataframe 
print('The shape of the edited Dataframe is:')
tor_df.shape
# Out:
# The shape of the edited Dataframe is:
# (103, 3)

# %% [markdown]
# # End Question 1
# ## -----------------------------

# %% [markdown]
# # Question 2: Geocoding

# %%
# establishing dataframe2
data2 = pd.read_csv('https://cocl.us/Geospatial_data')
data2.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# renaming Postal Code column
torzips_df = data2.rename(columns={'Postal Code':'PostalCode'})
torzips_df.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
# double-checking column names in two dataframes
tor_df.columns
# Out:
# Index(['PostalCode', 'Borough', 'Neighborhood'], dtype='object')

# %%
# double-checking column names in two dataframes 
torzips_df.columns
# Out:
# Index(['PostalCode', 'Latitude', 'Longitude'], dtype='object')

# %%
# merging the two dataframes
tor_merged = pd.merge(left=tor_df, right=torzips_df, left_on='PostalCode', right_on='PostalCode')

# %%
# confirming the shape of the new merged dataframe
tor_merged.shape
# Out:
# (103, 5)

# %%
# confirming the contents of the new merged dataframe
tor_merged.head()
# Out:
#   PostalCode           Borough                                  Neighborhood  \
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 3        M6A        North York             Lawrence Manor , Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# # End Question 2
# ## -----------------------------

# %% [markdown]
# # Question 3: Explore and Cluster neighborhoods in Toronoto on a map

# %%
# importing necessary packages
import random

# module to convert an address into latitude and longitude values
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

 # plotting library
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('done!')
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.8           |   py36h45558ae_2         628 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
# ...

# %% [markdown]
# ## First, I need to load the latitude and longitude coordinates of Toronto into variables

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ## Next, I'll use folium to create a map of the different neighborhoods - an overall view

# %%
# create a map of Toronto 
map_tor = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(tor_merged['Latitude'], tor_merged['Longitude'], tor_merged['Borough'], tor_merged['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5,
        parse_html=False).add_to(map_tor)  
    
#display map 
map_tor
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Now, I'll only look at the Downtown Toronto Borough

# %%
# new DataFrame for Downtown Toronto
downtown_data = tor_merged[tor_merged['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
downtown_data.head()
# Out:
#   PostalCode           Borough                                  Neighborhood  \
# 0        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 1        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
# 2        M5B  Downtown Toronto                      Garden District, Ryerson
# 3        M5C  Downtown Toronto                                St. James Town
# 4        M5E  Downtown Toronto                                   Berczy Park
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.644771 -79.373306

# %%
# confirming shape of new Downtown Toronto DataFrame
downtown_data.shape
# Out:
# (19, 5)

# %% [markdown]
# ## Now, I'll create a map only looking at the Downtown Toronto Neighborhoods

# %%
# create a map of Toronto 
map_downtown = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, borough, neighborhood in zip(downtown_data['Latitude'], downtown_data['Longitude'], downtown_data['Borough'], downtown_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.5,
        parse_html=False).add_to(map_downtown)  
    
#display map 
map_downtown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Defining FourSquare credentials

# %%
CLIENT_ID = 'E3ZQ5HY2IJMKKLIRD4VO4CIMALQJSMIN3KPEHQQYS4Z3FU22' # your Foursquare ID
CLIENT_SECRET = 'TXA2E5OSXNLRHITNY4FTUJVWG0OQZR0F1ZTFRN1TZ1L1DNZQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: E3ZQ5HY2IJMKKLIRD4VO4CIMALQJSMIN3KPEHQQYS4Z3FU22
# CLIENT_SECRET:TXA2E5OSXNLRHITNY4FTUJVWG0OQZR0F1ZTFRN1TZ1L1DNZQ

# %% [markdown]
# ## Exploring St. James Town neighborhood

# %%
downtown_data.loc[3, 'Neighborhood']
# Out:
# 'St. James Town'

# %%
# establishing latitude, longitude, and name of neighborhood
neighborhood_latitude = downtown_data.loc[3, 'Latitude']
neighborhood_longitude = downtown_data.loc[3, 'Longitude']
neighborhood_name = downtown_data.loc[3, 'Neighborhood']

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of St. James Town are 43.6514939, -79.3754179.

# %%
# setting up LIMIT and radius foursquare search parameters
LIMIT = 100 
radius = 500


# create URL 
url3 = 'https://api.foursquare.com/v2/venues/explore?&client_id=E3ZQ5HY2IJMKKLIRD4VO4CIMALQJSMIN3KPEHQQYS4Z3FU22&client_secret=TXA2E5OSXNLRHITNY4FTUJVWG0OQZR0F1ZTFRN1TZ1L1DNZQ&v=20180605&ll=43.6514939, -79.3754179&radius=500&limit=100'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

url3 # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=E3ZQ5HY2IJMKKLIRD4VO4CIMALQJSMIN3KPEHQQYS4Z3FU22&client_secret=TXA2E5OSXNLRHITNY4FTUJVWG0OQZR0F1ZTFRN1TZ1L1DNZQ&v=20180605&ll=43.6514939, -79.3754179&radius=500&limit=100'

# %%
# get the results of the search 
stjames_results = requests.get(url3).json()
stjames_results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9f136bc546f3001be4d748'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'St. Lawrence',
#   'headerFullLocation': 'St. Lawrence, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 84,
#   'suggestedBounds': {'ne': {'lat': 43.6559939045, 'lng': -79.36921018606671},
#    'sw': {'lat': 43.646993895499996, 'lng': -79.3816256139333}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574ad72238fa943556d93b8e',
#        'name': 'Gyu-Kaku Japanese BBQ',
#        'location': {'address': '81 Church St',
#         'crossStreet': 'at Adelaide St E',
#         'lat': 43.651422275497914,
# ...

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = stjames_results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                         name           categories        lat  \
# 0                      Gyu-Kaku Japanese BBQ  Japanese Restaurant  43.651422
# 1                                    Terroni   Italian Restaurant  43.650927
# 2  GoodLife Fitness Toronto 137 Yonge Street                  Gym  43.651242
# 3                          GEORGE Restaurant           Restaurant  43.653346
# 4                          Fahrenheit Coffee          Coffee Shop  43.652384
#
#          lng
# 0 -79.375047
# 1 -79.375602
# 2 -79.378068
# 3 -79.374445
# 4 -79.372719

# %%
print('{} St. James neighborhood venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 84 St. James neighborhood venues were returned by Foursquare.

# %% [markdown]
# # End Question 3
# ## -----------------------------
